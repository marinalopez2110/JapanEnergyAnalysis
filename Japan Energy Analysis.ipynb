# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("stte_2023a.xlsx", sheet_name=0) 
df
# Out:
#      2023FY           Unnamed: 1  \
# 0       NaN                  NaN
# 1       NaN                  NaN
# 2       NaN                  NaN
# 3       NaN  << Original Unit >>
# 4       NaN                固有単位表
# ..      ...                  ...
# 57      #36                  NaN
# 58      NaN                  NaN
# 59      #37                  NaN
# 60      NaN                  NaN
# 61   2023FY                  NaN
#
#                                            Unnamed: 2                   $  \
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# ..                                                ...                 ...
# ...

# %%
new_header = df.iloc[2] #grab the first row for the header
cl_df1 = df[14:] #take the data less the header row
cl_df1.columns = new_header #set the header row as the df header
cl_df1
# Out:
# 2       NaN  NaN                                                NaN  \
# 14      #01  NaN                              Primary Energy Supply
# 15      #02  NaN                              Indigenously Produced
# 16      #03  NaN                                           Imported
# 17      #04  NaN                        Total Primary Energy Supply
# 18      #05  NaN                                             Export
# 19      #06  NaN                         Stockpile Change / Supply
# 20      #07  NaN                     Domestic Primary Energy Supply
# 21      NaN  NaN                                                NaN
# 22      #08  NaN                    Energy Transformation & Own Use
# 23      #09  NaN                       Manufacture of Coal Products
# 24      #10  NaN                                       Oil Products
# 25      #11  NaN                      Gas Conversion and Production
# 26      #12  NaN                                   Power Generation
# ...
